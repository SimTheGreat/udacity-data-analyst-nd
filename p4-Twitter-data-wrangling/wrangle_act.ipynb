# %% [markdown]
# # Wrangle act

# %% [markdown]
# first we import all our libaries

# %%
import pandas as pd
import numpy as np
import requests
import tweepy
import json
import time
import matplotlib.pyplot as plt
import tweepy
from tweepy import OAuthHandler
import json
import os
from timeit import default_timer as timer
# %matplotlib inline
print('imports compleated')
# Out:
# imports compleated

# %% [markdown]
# # Gathering

# %% [markdown]
# in this data analasis we will load data from three different sources
# one will be a csv file one from the tweepy libary and one from a tsv file

# %% [markdown]
# now we load the witter-archive-enhanced.csv file as df_1

# %%
df_1=pd.read_csv('twitter-archive-enhanced.csv')

# %% [markdown]
# here I entered my api keys of tweepy and saw if the API codes were succsessfully implemented
# df_1 has api codes wich this code below gets data from using tweepys api

# %%
# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = df_1.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %%
weet_ids = df_1.tweet_id.values
print("# of tweet_ids: " + str(len(tweet_ids)) + "\n")

count = 0
tweet_json_list = []
fails_dict = {}

start_time = time.time()

for tweet_id in tweet_ids:
    count += 1
    try:
        # attempt to get the tweet's JSON data and append to the tweet JSON list
        tweet = api.get_status(tweet_id, tweet_mode = 'extended')
        tweet_json_list.append(tweet._json)
    except tweepy.TweepError as err:
        # save the error to the fail dictionary for review
        print("TweepError for id:  " + str(tweet_id))
        fails_dict[tweet_id] = err
        pass
    # To save space, only print out loop/tweet id for every 100th tweet
    if count % 100 == 0:
        print("loop # " + str(count))

elapsed_time = time.time() - start_time

elapsed_time_str = time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
print("\nTime elapse (HH:MM:SS):  " + elapsed_time_str + "\n")

# display list of tweets with errors
print("Number of TweepErrors:  {}\n".format(len(fails_dict)))
for tweet_id in fails_dict:
    print(tweet_id, fails_dict[tweet_id])
# Out:
# # of tweet_ids: 2356
#
# TweepError for id:  892420643555336193
# TweepError for id:  888202515573088257
# TweepError for id:  873697596434513921
# loop # 100
# TweepError for id:  872668790621863937
# TweepError for id:  872261713294495745
# TweepError for id:  869988702071779329
# TweepError for id:  866816280283807744
# TweepError for id:  861769973181624320
# TweepError for id:  856602993587888130
# loop # 200
# TweepError for id:  851953902622658560
# TweepError for id:  845459076796616705
# TweepError for id:  844704788403113984
# TweepError for id:  842892208864923648
# TweepError for id:  837366284874571778
# TweepError for id:  837012587749474308
# loop # 300
# TweepError for id:  829374341691346946
# TweepError for id:  827228250799742977
# loop # 400
# loop # 500
# TweepError for id:  812747805718642688
# TweepError for id:  802247111496568832
# loop # 600
# loop # 700
# TweepError for id:  779123168116150273
# TweepError for id:  775096608509886464
# loop # 800
# ...

# %%
tweet_json_file = 'tweet_json.txt'

# %%
with open(tweet_json_file, 'w') as outfile:
    for tweet_json in tweet_json_list:
        json.dump(tweet_json, outfile)
        outfile.write('\n')

# %%
ls tweet_json.txt
# Out:
# tweet_json.txt

# %% [markdown]
# and here we specify what data we want data we want to extract and then load it in to a df

# %%
tweet_json_data = []

with open(tweet_json_file, 'r') as json_file:
    # read the first line to start the loop
    line = json_file.readline()
    while line:
        data = json.loads(line)

        # extract variables from the JSON data
        data_id = data['id']
        data_retweet_count = data['retweet_count']
        data_favorite_count = data['favorite_count']
        
        
        json_data = {'tweet_id': data_id, 
                     'retweet_count': data_retweet_count, 
                     'favorite_count': data_favorite_count
                    }
        tweet_json_data.append(json_data)

        # read the next line of JSON data
        line = json_file.readline()
        # ----- while -----

# convert the tweet JSON data dictionary list to a df
df_tweet_data_extra = pd.DataFrame(tweet_json_data, 
                                   columns = ['tweet_id',
                                              'retweet_count',
                                              'favorite_count'])

df_tweet_data_extra.head(30)
# Out:
#               tweet_id  retweet_count  favorite_count
# 0   892177421306343426           5662           31070
# 1   891815181378084864           3757           23375
# 2   891689557279858688           7833           39287
# 3   891327558926688256           8430           37520
# 4   891087950875897856           2828           18905
# 5   890971913173991426           1842           10989
# 6   890729181411237888          17106           60669
# 7   890609185150312448           3891           26016
# 8   890240255349198849           6655           29721
# 9   890006608113172480           6639           28602
# 10  889880896479866881           4520           26033
# 11  889665388333682689           9061           44806
# 12  889638837579907072           4060           25223
# 13  889531135344209921           2048           14136
# 14  889278841981685760           4834           23503
# 15  888917238123831296           4069           27137
# ...

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)
response
#200 means good
# Out:
# <Response [200]>

# %%
file_images = url.split('/')[-1]

with open(os.path.join('./', file_images), mode = 'wb') as file:
    file.write(response.content)

# %%
ls *.tsv
# Out:
# image-predictions (1).tsv  image-predictions.tsv

# %% [markdown]
# now we rename df1 and df_tweet_data_extra and load convert our tsv file into a csv and then read it

# %%
archive_df = pd.read_csv('twitter-archive-enhanced.csv')
predictions_df = pd.read_csv('image-predictions.tsv', sep = '\\t', engine = 'python')

# %%
df_tweet_data_extra.to_csv('tweet_data_extra.csv', index = False)
json_txt_df=pd.read_csv('tweet_data_extra.csv')

# %% [markdown]
# # Assessing

# %% [markdown]
# now I identify the quality and tidyness issues and list them below

# %%
json_txt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2330 entries, 0 to 2329
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2330 non-null   int64
#  1   retweet_count   2330 non-null   int64
#  2   favorite_count  2330 non-null   int64
# dtypes: int64(3)
# memory usage: 54.7 KB

# %%
json_txt_df
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892177421306343426           5662           31070
# 1     891815181378084864           3757           23375
# 2     891689557279858688           7833           39287
# 3     891327558926688256           8430           37520
# 4     891087950875897856           2828           18905
# ...                  ...            ...             ...
# 2325  666049248165822465             40              96
# 2326  666044226329800704            130             271
# 2327  666033412701032449             41             112
# 2328  666029285002620928             42             121
# 2329  666020888022790149            460            2397
#
# [2330 rows x 3 columns]

# %%
archive_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
archive_df
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
archive_df.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
archive_df[archive_df.rating_denominator==11]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 784   775096608509886464                    NaN                  NaN
# 1068  740373189193256964                    NaN                  NaN
# 1662  682962037429899265                    NaN                  NaN
#
#                       timestamp  \
# 784   2016-09-11 22:20:06 +0000
# 1068  2016-06-08 02:41:38 +0000
# 1662  2016-01-01 16:30:13 +0000
#
#                                                  source  \
# 784   <a href="http://twitter.com/download/iphone" r...
# 1068  <a href="http://twitter.com/download/iphone" r...
# 1662  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 784   RT @dog_rates: After so many requests, this is...         7.403732e+17
# 1068  After so many requests, this is Bretagne. She ...                  NaN
# 1662  This is Darrel. He just robbed a 7/11 and is i...                  NaN
#
# ...

# %%
len(archive_df.in_reply_to_status_id.value_counts())
# Out:
# 77

# %%
sum(archive_df.duplicated())
# Out:
# 0

# %%
sum(archive_df.name.str.islower())
# Out:
# 109

# %%
archive_df.name.value_counts().head(60)
# Out:
# None        745
# a            55
# Charlie      12
# Oliver       11
# Lucy         11
# Cooper       11
# Penny        10
# Lola         10
# Tucker       10
# Bo            9
# Winston       9
# the           8
# Sadie         8
# an            7
# Daisy         7
# Buddy         7
# Bailey        7
# Toby          7
# Koda          6
# Milo          6
# Leo           6
# Stanley       6
# Bella         6
# Dave          6
# Scout         6
# Jack          6
# Jax           6
# Oscar         6
# Rusty         6
# very          5
# Sunny         5
# Louis         5
# Sammy         5
# George        5
# Chester       5
# Oakley        5
# Alfie         5
# Bentley       5
# Phil          5
# Finn          5
# Gus           5
# Larry         5
# Cassie        4
# Boomer        4
# Gerald        4
# Maggie        4
# Clark         4
# Archie        4
# Luna          4
# Dexter        4
# Sophie        4
# Riley         4
# Reginald      4
# quite         4
# Maximus       4
# ...

# %%
archive_df.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
predictions_df
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
predictions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
json_txt_df
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892177421306343426           5662           31070
# 1     891815181378084864           3757           23375
# 2     891689557279858688           7833           39287
# 3     891327558926688256           8430           37520
# 4     891087950875897856           2828           18905
# ...                  ...            ...             ...
# 2325  666049248165822465             40              96
# 2326  666044226329800704            130             271
# 2327  666033412701032449             41             112
# 2328  666029285002620928             42             121
# 2329  666020888022790149            460            2397
#
# [2330 rows x 3 columns]

# %%
archive_df.rating_numerator.value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
archive_df.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %% [markdown]
# # notes

# %% [markdown]
# Quality issues:

# %% [markdown]
# <ul>
#     <li>displaying the floats in the ratings
# <li>wrog dtypes:tweet_id in archive,predictions,json_df is a integar,timestamp  in archive is in wrong data type
# <li>drop invalid names
#
#   <li>source	in archive df is not really a source but incloudes some of the html code
#    <li>4 tweets have the correct rating within the text, and can be manually fixed:
# 740373189193256964: replace 9/11 with 14/10
# 716439118184652801: replace 50/50 with 11/10
# 682962037429899265: replace 7/11 with 10/10
# 666287406224695296: replace 1/2 with 9/10
#        <li>all rows about multiple dogs/pups, and can be dropped
#     <li>Drop all rows containing retweets since we only want original tweets
#     <li>drop all rows without extended url
#     <li>some tweets have giant rating_numerator
# </ul>

# %% [markdown]
# tidyness issues:

# %% [markdown]
# <ul>
# <li>doggo,floofer,pupper and puppo should be in one row
#  <li>we technicly do not need the rating_denominator sice all values are 10
#    <li>The json_data table should be part of the archive tablea nd at the end combine all three df's
#       <li>
# </ul>

# %% [markdown]
# # Quality

# %%
archive=archive_df.copy()
predictions=predictions_df.copy()
json_df=json_txt_df.copy()

# %% [markdown]
# def:convert rating_numerator as an integar and then get the correct number displayed

# %% [markdown]
# code:

# %%
archive.rating_numerator = archive.rating_numerator.astype(float)

# %%
ratings = archive.text.str.extract('((?:\d+\.)?\d+)\/(\d+)', expand=True)
archive.rating_numerator = ratings

# %% [markdown]
# test:

# %%
archive[archive.tweet_id=='786709082849828864']
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 501  786709082849828864                    NaN                  NaN
#
#               timestamp              source  \
# 501 2016-10-13 23:23:56  Twitter for iPhone
#
#                                                   text  retweeted_status_id  \
# 501  This is Logan, the Chow who lived. He solemnly...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 501                       NaN                        NaN
#
#                                          expanded_urls rating_numerator  \
# 501  https://twitter.com/dog_rates/status/786709082...             9.75
#
#       name  retweet_count  favorite_count stage       breed  confidence
# 501  Logan         6209.0         18482.0  none  Pomeranian          46

# %% [markdown]
# def:convert tweet_id in archive,predictions,json_df as a string using .astype()

# %% [markdown]
# code:

# %%
archive.tweet_id = archive.tweet_id.astype(str)
predictions.tweet_id = predictions.tweet_id.astype(str)
json_df.tweet_id = json_df.tweet_id.astype(str)

# %%
archive.timestamp=archive.timestamp.astype('datetime64')

# %% [markdown]
# test:

# %%
archive.dtypes
# Out:
# tweet_id                              object
# in_reply_to_status_id                float64
# in_reply_to_user_id                  float64
# timestamp                     datetime64[ns]
# source                                object
# text                                  object
# retweeted_status_id                  float64
# retweeted_status_user_id             float64
# retweeted_status_timestamp            object
# expanded_urls                         object
# rating_numerator                      object
# name                                  object
# retweet_count                        float64
# favorite_count                       float64
# stage                               category
# breed                                 object
# confidence                             int64
# dtype: object

# %%
predictions.dtypes
# Out:
# tweet_id     object
# jpg_url      object
# img_num       int64
# p1           object
# p1_conf     float64
# p1_dog         bool
# p2           object
# p2_conf     float64
# p2_dog         bool
# p3           object
# p3_conf     float64
# p3_dog         bool
# dtype: object

# %%
json_df.dtypes
# Out:
# tweet_id          object
# retweet_count      int64
# favorite_count     int64
# dtype: object

# %% [markdown]
# def: convert all invalid names into none

# %% [markdown]
# code:

# %%
names_mask = archive.name.str.contains('^[a-z]', regex = True)
archive[names_mask].name.value_counts().sort_index()
archive.loc[names_mask, 'name'] = "none"

# %% [markdown]
# test:

# %%
archive[names_mask].name.value_counts()
# Out:
# none    96
# Name: name, dtype: int64

# %% [markdown]
# def:  covert 4 ratings manually from the text

# %% [markdown]
# code:

# %%
mask_row1 = archive.tweet_id == '740373189193256964'
archive.loc[mask_row1, 'rating_numerator'] = 14
archive.loc[mask_row1, 'rating_denominator'] = 10

# %%
mask_row2 = archive.tweet_id == '716439118184652801'
archive.loc[mask_row2, 'rating_numerator'] = 11
archive.loc[mask_row2, 'rating_denominator'] = 10

# %%
mask_row3 = archive.tweet_id == '682962037429899265'
archive.loc[mask_row3, 'rating_numerator'] = 10
archive.loc[mask_row3, 'rating_denominator'] = 10

# %%
mask_row4 = archive.tweet_id == '666287406224695296'
archive.loc[mask_row4, 'rating_numerator'] = 9
archive.loc[mask_row4, 'rating_denominator'] = 10

# %% [markdown]
# test:

# %%
archive[archive.tweet_id=='740373189193256964']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1068  740373189193256964                    NaN                  NaN
#
#                timestamp                                             source  \
# 1068 2016-06-08 02:41:38  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1068  After so many requests, this is Bretagne. She ...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1068                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1068  https://twitter.com/dog_rates/status/740373189...                14
#
#       rating_denominator  name doggo floofer pupper puppo
# 1068                  10  None  None    None   None  None

# %%
archive[archive.tweet_id=='716439118184652801']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1202  716439118184652801                    NaN                  NaN
#
#                timestamp                                             source  \
# 1202 2016-04-03 01:36:11  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1202  This is Bluebert. He just saw that both #Final...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1202                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1202  https://twitter.com/dog_rates/status/716439118...                11
#
#       rating_denominator      name doggo floofer pupper puppo
# 1202                  10  Bluebert  None    None   None  None

# %%
archive[archive.tweet_id=='682962037429899265']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1662  682962037429899265                    NaN                  NaN
#
#                timestamp                                             source  \
# 1662 2016-01-01 16:30:13  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1662  This is Darrel. He just robbed a 7/11 and is i...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1662                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1662  https://twitter.com/dog_rates/status/682962037...                10
#
#       rating_denominator    name doggo floofer pupper puppo
# 1662                  10  Darrel  None    None   None  None

# %%
archive[archive.tweet_id=='666287406224695296']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2335  666287406224695296                    NaN                  NaN
#
#                timestamp                                             source  \
# 2335 2015-11-16 16:11:11  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2335  This is an Albanian 3 1/2 legged  Episcopalian...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 2335                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 2335  https://twitter.com/dog_rates/status/666287406...                 9
#
#       rating_denominator  name doggo floofer pupper puppo
# 2335                  10  none  None    None   None  None

# %% [markdown]
# def: remove all rating denominator that are not 10

# %% [markdown]
# code:

# %%
archive = archive[archive.rating_denominator == 10]

# %% [markdown]
# test:

# %%
archive.rating_denominator.value_counts()
# Out:
# 10    2337
# Name: rating_denominator, dtype: int64

# %% [markdown]
# def:classify archives source column in four observed sources

# %% [markdown]
# code:

# %%
archive['source'] = archive['source'].str.extract('^<a.+>(.+)</a>$')

# %% [markdown]
# test:

# %%
archive.source.value_counts()
# Out:
# Twitter for iPhone     2202
# Vine - Make a Scene      91
# Twitter Web Client       33
# TweetDeck                11
# Name: source, dtype: int64

# %% [markdown]
# def:remove retweets since we only want original tweets

# %% [markdown]
# code:

# %%
archive = archive[archive.retweeted_status_id.isna()]

# %% [markdown]
# test:

# %%
archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2157 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2157 non-null   object
#  1   in_reply_to_status_id       73 non-null     float64
#  2   in_reply_to_user_id         73 non-null     float64
#  3   timestamp                   2157 non-null   datetime64[ns]
#  4   source                      2157 non-null   object
#  5   text                        2157 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2103 non-null   object
#  10  rating_numerator            2157 non-null   int64
#  11  rating_denominator          2157 non-null   int64
#  12  name                        2157 non-null   object
# ...

# %%
archive.retweeted_status_id.value_counts()
# Out:
# Series([], Name: retweeted_status_id, dtype: int64)

# %% [markdown]
# def:drop all rows with no extended url

# %% [markdown]
# code:

# %%
archive = archive[archive.expanded_urls.notnull()]

# %% [markdown]
# test:

# %%
archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                timestamp              source  \
# 0    2017-08-01 16:23:56  Twitter for iPhone
# ...

# %% [markdown]
# def:merge json_df into archive using pandas merge

# %% [markdown]
# code:

# %%
archive= pd.merge(archive, json_df, 
                         on = 'tweet_id', how = 'left')

# %% [markdown]
# test:

# %%
archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2103 entries, 0 to 2102
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2103 non-null   object
#  1   in_reply_to_status_id       22 non-null     float64
#  2   in_reply_to_user_id         22 non-null     float64
#  3   timestamp                   2103 non-null   datetime64[ns]
#  4   source                      2103 non-null   object
#  5   text                        2103 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2103 non-null   object
#  10  rating_numerator            2103 non-null   int64
#  11  rating_denominator          2103 non-null   int64
#  12  name                        2103 non-null   object
# ...

# %% [markdown]
# def:deleate all rows having a higher rating_numerator then 1775 since we need to incloud the po

# %% [markdown]
# code:

# %%
archive=archive[archive.rating_numerator < 1775]

# %% [markdown]
# test:

# %%
archive.rating_numerator.value_counts()
# Out:
# 12     489
# 10     437
# 11     418
# 13     295
# 9      154
# 8       98
# 7       51
# 14      41
# 5       34
# 6       32
# 3       19
# 4       15
# 2        9
# 1        4
# 0        2
# 75       1
# 26       1
# 27       1
# 420      1
# Name: rating_numerator, dtype: int64

# %%
archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2098  666049248165822465                    NaN                  NaN
# 2099  666044226329800704                    NaN                  NaN
# 2100  666033412701032449                    NaN                  NaN
# 2101  666029285002620928                    NaN                  NaN
# 2102  666020888022790149                    NaN                  NaN
#
#                timestamp              source  \
# 0    2017-08-01 16:23:56  Twitter for iPhone
# ...

# %% [markdown]
# def:create dummy column for none,create new column stage for doggo/floofer/pupper/puppo/ remove old columns

# %% [markdown]
# code:

# %%
make_dummy = lambda x: 0 if x == 'None' else 1

archive.doggo = archive.doggo.apply(make_dummy)
archive.floofer = archive.floofer.apply(make_dummy)
archive.pupper = archive.pupper.apply(make_dummy)
archive.puppo = archive.puppo.apply(make_dummy)
archive['none'] = archive['doggo'] + archive['floofer'] + \
                        archive['pupper'] + archive['puppo']

# %%
stage_none = lambda x: 1 if x == 0 else 0 
archive['none'] = archive['none'].apply(stage_none)

stage = ['floofer', 'puppo', 'doggo', 'pupper', 'none']
conditions = [
    (archive[stage[0]] == 1),
    (archive[stage[1]] == 1),
    (archive[stage[2]] == 1),
    (archive[stage[3]] == 1),
    (archive[stage[4]] == 1)]

archive['stage'] = np.select(conditions, stage, default = stage[4])
archive.drop(stage, axis = 1, inplace = True)
archive['stage'] = archive.stage.astype('category')

# %% [markdown]
# test:

# %%
archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2102 entries, 0 to 2102
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2102 non-null   object
#  1   in_reply_to_status_id       22 non-null     float64
#  2   in_reply_to_user_id         22 non-null     float64
#  3   timestamp                   2102 non-null   datetime64[ns]
#  4   source                      2102 non-null   object
#  5   text                        2102 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2102 non-null   object
#  10  rating_numerator            2102 non-null   int64
#  11  rating_denominator          2102 non-null   int64
#  12  name                        2102 non-null   object
# ...

# %% [markdown]
# def:drop rating_denominator since all values are 10

# %% [markdown]
# code:

# %%
archive=archive.drop(['rating_denominator'], axis=1)

# %% [markdown]
# test:

# %%
archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2102 entries, 0 to 2102
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2102 non-null   object
#  1   in_reply_to_status_id       22 non-null     float64
#  2   in_reply_to_user_id         22 non-null     float64
#  3   timestamp                   2102 non-null   datetime64[ns]
#  4   source                      2102 non-null   object
#  5   text                        2102 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2102 non-null   object
#  10  rating_numerator            2102 non-null   int64
#  11  name                        2102 non-null   object
#  12  retweet_count               2094 non-null   float64
# ...

# %% [markdown]
# def:combine predictions and archive

# %% [markdown]
# code:

# %%
conditions = [(predictions['p1_dog'] == True),
              (predictions['p2_dog'] == True),
              (predictions['p3_dog'] == True)]
choices_breed = [predictions['p1'], 
                 predictions['p2'],
                 predictions['p3']]
choices_confidence = [predictions['p1_conf'], 
                      predictions['p2_conf'], 
                      predictions['p3_conf']]
predictions['breed'] = np.select(conditions, choices_breed, 
                                       default = 'none')
predictions['confidence'] = np.select(conditions, choices_confidence, 
                                            default = 0)
mask_cols = ['tweet_id', 'breed', 'confidence']
archive = pd.merge(archive, predictions[mask_cols],
                         on = 'tweet_id', how = 'inner')
archive.confidence = (archive.confidence * 100).astype(int)

predictions.drop(['breed', 'confidence'], axis = 1, inplace = True)

# %% [markdown]
# test:

# %%
archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1979 entries, 0 to 1978
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    1979 non-null   object
#  1   in_reply_to_status_id       22 non-null     float64
#  2   in_reply_to_user_id         22 non-null     float64
#  3   timestamp                   1979 non-null   datetime64[ns]
#  4   source                      1979 non-null   object
#  5   text                        1979 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               1979 non-null   object
#  10  rating_numerator            1979 non-null   int64
#  11  name                        1979 non-null   object
#  12  retweet_count               1971 non-null   float64
# ...

# %% [markdown]
# # storing my work

# %%
archive.to_csv('twitter_archive_master.csv', index = False)#my master df
predictions.to_csv('predictions.csv', index = False)
json_df.to_csv('json.csv', index = False)

# %% [markdown]
# # Analyze Data

# %% [markdown]
# <bold>observation 1</bold>

# %%
archive['retweet_count'].plot(kind = 'bar');

plt.xlim(0, 15);
plt.ylim(0, 25000);
plt.xlabel('rating_numerator');
plt.ylabel('retweet_count');
plt.title('ratings with retweet_count');

# %% [markdown]
# in this graph above you can see that the rating 7 has the most amount of retweet count

# %% [markdown]
# observation 2

# %%
archive['rating_numerator']
archive['favorite_count']
plt.bar(archive['rating_numerator'],archive['favorite_count'])
plt.xlim(0, 15);
plt.xlabel('rating_numerator');
plt.ylabel('favorite_count');
plt.title('ratings with favorite_count');

# %% [markdown]
# this graph is left skewd and showing that the the post with a 13 rating have the most favourite count

# %% [markdown]
# observation 3

# %%
a=archive.favorite_count.describe()[6]

# %%
plt.pie(archive[archive.favorite_count>a].breed.value_counts().head(5));
plt.legend(['none 65','golden_retriever 63','Labrador_retriever 36','Pembroke 34','Chihuahua 19'], 
          title="breeds in the piechart",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1));
plt.title('top 5 breeds with a fovourite count above the 75% quartile');

# %%
archive[archive.favorite_count>a].breed.value_counts()
# Out:
# golden_retriever      63
# none                  63
# Labrador_retriever    36
# Pembroke              33
# Chihuahua             19
#                       ..
# komondor               1
# Maltese_dog            1
# borzoi                 1
# Newfoundland           1
# Yorkshire_terrier      1
# Name: breed, Length: 91, dtype: int64

# %% [markdown]
# here you can see that the most common breeds with a favourite count above the 75% quartile

# %% [markdown]
# observation 4

# %%
plt.scatter(archive.favorite_count,archive.retweet_count);
plt.xlim(0, 16000);
plt.ylim(0, 7000);

plt.xlabel('favorite_count');
plt.ylabel('retweet_count');
plt.title('favorite_count and retweet_count');

# %% [markdown]
# here you can see that there is a direct conection between favorite_count and retweet_count

# %% [markdown]
# observation 4:

# %%
plt.pie(archive.stage.value_counts());
plt.legend(['none','pupper','doggo','puppo ','floofer'],title="stage",
          loc="lower right",bbox_to_anchor=(1, 0, 0.5, 0.8));
plt.title('pie plot of different stages');

# %% [markdown]
# you can see that this pieplot displays mostly none values

# %%
archive.stage.value_counts()
# Out:
# none       1673
# pupper      203
# doggo        72
# puppo        23
# floofer       8
# Name: stage, dtype: int64

# %% [markdown]
# obversatin5:

# %%
import seaborn as sns

# %%
sns.pairplot(archive, 
             vars = ['rating_numerator', 'retweet_count', 'favorite_count', ], 
             diag_kind = 'kde', plot_kws = {'alpha': 0.5},palette="ch:2.5,-.2,dark=.3")

# %% [markdown]
# these plots show to corrolation between the rating numorator,retweet count and favourite count

# %% [markdown]
# observation6

# %%
plt.scatter(archive.confidence,archive.favorite_count)
plt.axvline(archive.confidence.mean(),linewidth=1, color='r')
plt.xlabel('cofidence');
plt.ylabel('favourite_cout');
plt.title('corrolation between confidence and favourite count');

# %% [markdown]
# there does not seem to be a corrolation between favourite count and confidence

# %%
archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 1974  666049248165822465                    NaN                  NaN
# 1975  666044226329800704                    NaN                  NaN
# 1976  666033412701032449                    NaN                  NaN
# 1977  666029285002620928                    NaN                  NaN
# 1978  666020888022790149                    NaN                  NaN
#
#                timestamp              source  \
# 0    2017-08-01 16:23:56  Twitter for iPhone
# ...
